# %% [markdown]
# **Bukti Kehadiran**

# %%
from sympy import Matrix

# %%
Matrix([1,2,3])
# Out:
# Matrix([
# [1],
# [2],
# [3]])

# %%
Matrix([[1,2,3]])
# Out:
# Matrix([[1, 2, 3]])

# %%
Matrix([[1,2,3],[5,6,7]])
# Out:
# Matrix([
# [1, 2, 3],
# [5, 6, 7]])

# %%
A = Matrix([[4,5,6],[8,9,7]])

# %%
A
# Out:
# Matrix([
# [4, 5, 6],
# [8, 9, 7]])

# %% [markdown]
# Matriks A baris 0 kolom 1

# %%
A[0,1]
# Out:
# 5

# %%
A[0,:]
# Out:
# Matrix([[4, 5, 6]])

# %%
A[:,0]
# Out:
# Matrix([
# [4],
# [8]])

# %%
A[:,:]
# Out:
# Matrix([
# [4, 5, 6],
# [8, 9, 7]])

# %%
import matplotlib.pyplot as plt

# %%
x = [0,1]
y = [0,1]
plt.plot(x,y)

# %%
x = [0,1,2,0]
y = [0,1,0,0]
plt.plot(x,y)

# %%
x = [0,0,1,1,0]
y = [0,1,1,0,0]
plt.plot(x,y)

# %%
x = [0,1,2,0]
y = [0,1,0,0]
M = Matrix([x,y])
M
# Out:
# Matrix([
# [0, 1, 2, 0],
# [0, 1, 0, 0]])

# %%
t = Matrix([[2,0],[0,2]])
t
# Out:
# Matrix([
# [2, 0],
# [0, 2]])

# %%
H = t * M
H
# Out:
# Matrix([
# [0, 2, 4, 0],
# [0, 2, 0, 0]])

# %%
xh = [0,2,4,0]
yh = [0,2,0,0]
plt.plot(xh,yh)
x = [0,1,2,0]
y = [0,1,0,0]
plt.plot(x,y)

# %%
x = [0,1,2,0]
y = [0,1,0,0]
M = Matrix([x,y])
M
# Out:
# Matrix([
# [0, 1, 2, 0],
# [0, 1, 0, 0]])

# %%
t = Matrix([[1,0],[0,-1]])
t
# Out:
# Matrix([
# [1,  0],
# [0, -1]])

# %%
H = t * M
H
# Out:
# Matrix([
# [0,  1, 2, 0],
# [0, -1, 0, 0]])

# %%
xh = [0,1,2,0]
yh = [0,-1,0,0]
plt.plot(xh,yh)
x = [0,1,2,0]
y = [0,1,0,0]
plt.plot(x,y)
